# %%
import openml
import pandas as pd

# %%
def getValidDatasets(numFeatures = 50, numInstances=1000, numClasses=15,
                         missingValues = False, numericFeaturesOnly = True):
    openml_list = openml.datasets.list_datasets()  # returns a dict

    # Show a nice table with some key data properties
    datalist = pd.DataFrame.from_dict(openml_list, orient="index")

    datalist = datalist[datalist["NumberOfFeatures"]< numFeatures]
    datalist = datalist[datalist["NumberOfInstances"]< numInstances]
    datalist = datalist[datalist["NumberOfClasses"]< numClasses]

    if not missingValues:
        datalist = datalist[datalist["NumberOfMissingValues"]== 0]
    if numericFeaturesOnly:
        datalist= datalist[datalist["NumberOfSymbolicFeatures"]==0]

    return datalist

# %%
def describeDataset(dataset):
    propertiesList=dataset.qualities
    propertiesDf = pd.DataFrame(propertiesList.items(), columns=["key", "value"])
    AUCList = propertiesDf[propertiesDf["key"].str.contains("AUC")]
    meanAUC = AUCList.mean()
    
    return meanAUC

# %%
validDatasets= getValidDatasets()
validDatasetsId = validDatasets.index.tolist()
datasetsArray = []
for id in validDatasetsId:
    dataset = openml.datasets.get_dataset(id, download_data=False)
    mean = describeDataset(dataset)
    print(id, mean)
    datasetsArray.append([id, mean])
# Out:
# 8 value   NaN
# dtype: float64
# 191 value   NaN
# dtype: float64
# 192 value   NaN
# dtype: float64
# 193 value   NaN
# dtype: float64
# 207 value   NaN
# dtype: float64
# 208 value   NaN
# dtype: float64
# 211 value   NaN
# dtype: float64
# 212 value   NaN
# dtype: float64
# 214 value   NaN
# dtype: float64
# 217 value   NaN
# dtype: float64
# 223 value   NaN
# dtype: float64
# 226 value   NaN
# dtype: float64
# 229 value   NaN
# dtype: float64
# 230 value   NaN
# dtype: float64
# 406 value   NaN
# dtype: float64
# 426 value   NaN
# dtype: float64
# 427 value   NaN
# dtype: float64
# 428 value   NaN
# dtype: float64
# 429 value   NaN
# dtype: float64
# 431 value   NaN
# dtype: float64
# 433 value   NaN
# dtype: float64
# 434 value   NaN
# dtype: float64
# 440 value   NaN
# dtype: float64
# 441 value   NaN
# dtype: float64
# 487 value   NaN
# dtype: float64
# 508 value   NaN
# dtype: float64
# 509 value   NaN
# dtype: float64
# 518 value   NaN
# dtype: float64
# 519 value   NaN
# dtype: float64
# 522 value   NaN
# dtype: float64
# 528 value   NaN
# dtype: float64
# 530 value   NaN
# dtype: float64
# 540 value   NaN
# dtype: float64
# 542 value   NaN
# dtype: float64
# 544 value   NaN
# dtype: float64
# 547 value   NaN
# dtype: float64
# 549 value   NaN
# dtype: float64
# 552 value   NaN
# dtype: float64
# 560 value   NaN
# dtype: float64
# 579 value   NaN
# dtype: float64
# 581 value   NaN
# dtype: float64
# 582 value   NaN
# dtype: float64
# 584 value   NaN
# dtype: float64
# 585 value   NaN
# dtype: float64
# 591 value   NaN
# dtype: float64
# 594 value   NaN
# dtype: float64
# 596 value   NaN
# dtype: float64
# 597 value   NaN
# dtype: float64
# 601 value   NaN
# dtype: float64
# 602 value   NaN
# dtype: float64
# 604 value   NaN
# dtype: float64
# 605 value   NaN
# dtype: float64
# 611 value   NaN
# dtype: float64
# 613 value   NaN
# dtype: float64
# 614 value   NaN
# dtype: float64
# 615 value   NaN
# dtype: float64
# 617 value   NaN
# dtype: float64
# 621 value   NaN
# dtype: float64
# 624 value   NaN
# dtype: float64
# 625 value   NaN
# dtype: float64
# 627 value   NaN
# dtype: float64
# 629 value   NaN
# dtype: float64
# 631 value   NaN
# dtype: float64
# 633 value   NaN
# dtype: float64
# 634 value   NaN
# dtype: float64
# 635 value   NaN
# dtype: float64
# 639 value   NaN
# dtype: float64
# 640 value   NaN
# dtype: float64
# 641 value   NaN
# dtype: float64
# 643 value   NaN
# dtype: float64
# 644 value   NaN
# dtype: float64
# 646 value   NaN
# dtype: float64
# 647 value   NaN
# dtype: float64
# 649 value   NaN
# dtype: float64
# 651 value   NaN
# dtype: float64
# 653 value   NaN
# dtype: float64
# 654 value   NaN
# dtype: float64
# 655 value   NaN
# dtype: float64
# 656 value   NaN
# dtype: float64
# 657 value   NaN
# dtype: float64
# 658 value   NaN
# dtype: float64
# 659 value   NaN
# dtype: float64
# 660 value   NaN
# dtype: float64
# 663 value   NaN
# dtype: float64
# 664 value   NaN
# dtype: float64
# 666 value   NaN
# dtype: float64
# 668 value   NaN
# dtype: float64
# 670 value   NaN
# dtype: float64
# 671 value   NaN
# dtype: float64
# 672 value   NaN
# dtype: float64
# 673 value   NaN
# dtype: float64
# 674 value   NaN
# dtype: float64
# 675 value   NaN
# dtype: float64
# 676 value   NaN
# dtype: float64
# 678 value   NaN
# dtype: float64
# 684 value   NaN
# dtype: float64
# 687 value   NaN
# dtype: float64
# 689 value   NaN
# dtype: float64
# 690 value   NaN
# dtype: float64
# 691 value   NaN
# dtype: float64
# 692 value   NaN
# dtype: float64
# 693 value   NaN
# dtype: float64
# 695 value   NaN
# dtype: float64
# 696 value   NaN
# dtype: float64
# 698 value   NaN
# dtype: float64
# 699 value   NaN
# dtype: float64
# 704 value   NaN
# dtype: float64
# 707 value   NaN
# dtype: float64
# 708 value   NaN
# dtype: float64
# 709 value   NaN
# dtype: float64
# 710 value   NaN
# dtype: float64
# 711 value   NaN
# dtype: float64
# 712 value   NaN
# dtype: float64
# 1027 value   NaN
# dtype: float64
# 1035 value   NaN
# dtype: float64
# 1058 value   NaN
# dtype: float64
# 1089 value   NaN
# dtype: float64
# 1091 value   NaN
# dtype: float64
# 1096 value   NaN
# dtype: float64
# 1097 value   NaN
# dtype: float64
# 1099 value   NaN
# dtype: float64
# 1435 value   NaN
# dtype: float64
# 1571 value   NaN
# dtype: float64
# 1574 value   NaN
# dtype: float64
# 40505 key      NaN
# value    NaN
# dtype: object
# 40601 key      NaN
# value    NaN
# dtype: object
# 41514 key      NaN
# value    NaN
# dtype: object
# 41515 key      NaN
# value    NaN
# dtype: object
# 41516 key      NaN
# value    NaN
# dtype: object
# 41517 key      NaN
# value    NaN
# dtype: object
# 41518 key      NaN
# value    NaN
# dtype: object
# 41519 key      NaN
# value    NaN
# dtype: object
# 41943 key      NaN
# value    NaN
# dtype: object
# 42351 key      NaN
# value    NaN
# dtype: object
# 42352 key      NaN
# value    NaN
# dtype: object
# 42360 key      NaN
# value    NaN
# dtype: object
# 42361 key      NaN
# value    NaN
# dtype: object
# 42364 key      NaN
# value    NaN
# dtype: object
# 42368 key      NaN
# value    NaN
# dtype: object
# 42370 key      NaN
# value    NaN
# dtype: object
# 42372 key      NaN
# value    NaN
# dtype: object
# 42436 key      NaN
# value    NaN
# dtype: object
# 42437 key      NaN
# value    NaN
# dtype: object
# 42438 key      NaN
# value    NaN
# dtype: object
# 42439 key      NaN
# value    NaN
# dtype: object
# 42444 key      NaN
# value    NaN
# dtype: object
# 42445 key      NaN
# value    NaN
# dtype: object
# 42665 key      NaN
# value    NaN
# dtype: object
# 42900 key      NaN
# value    NaN
# dtype: object
# 43123 key      NaN
# value    NaN
# dtype: object

# %%
# Out:
# OrderedDict([(2,
#               {'tid': 2,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 2,
#                'name': 'anneal',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '2',
#                'target_feature': 'class',
#                'MajorityClassSize': 684,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 8,
#                'NumberOfClasses': 5,
#                'NumberOfFeatures': 39,
#                'NumberOfInstances': 898,
#                'NumberOfInstancesWithMissingValues': 898,
#                'NumberOfMissingValues': 22175,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 33}),
#              (3,
#               {'tid': 3,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 3,
#                'name': 'kr-vs-kp',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '3',
#                'target_feature': 'class',
#                'MajorityClassSize': 1669,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 1527,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 37,
#                'NumberOfInstances': 3196,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 37}),
#              (4,
#               {'tid': 4,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 4,
#                'name': 'labor',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '4',
#                'target_feature': 'class',
#                'MajorityClassSize': 37,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 20,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 57,
#                'NumberOfInstancesWithMissingValues': 56,
#                'NumberOfMissingValues': 326,
#                'NumberOfNumericFeatures': 8,
#                'NumberOfSymbolicFeatures': 9}),
#              (5,
#               {'tid': 5,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 5,
#                'name': 'arrhythmia',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '5',
#                'target_feature': 'class',
#                'MajorityClassSize': 245,
#                'MaxNominalAttDistinctValues': 13,
#                'MinorityClassSize': 2,
#                'NumberOfClasses': 13,
#                'NumberOfFeatures': 280,
#                'NumberOfInstances': 452,
#                'NumberOfInstancesWithMissingValues': 384,
#                'NumberOfMissingValues': 408,
#                'NumberOfNumericFeatures': 206,
#                'NumberOfSymbolicFeatures': 74}),
#              (6,
#               {'tid': 6,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 6,
#                'name': 'letter',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '6',
#                'target_feature': 'class',
#                'MajorityClassSize': 813,
#                'MaxNominalAttDistinctValues': 26,
#                'MinorityClassSize': 734,
#                'NumberOfClasses': 26,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 20000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 16,
#                'NumberOfSymbolicFeatures': 1}),
#              (7,
#               {'tid': 7,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 7,
#                'name': 'audiology',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '7',
#                'target_feature': 'class',
#                'MajorityClassSize': 57,
#                'MaxNominalAttDistinctValues': 24,
#                'MinorityClassSize': 1,
#                'NumberOfClasses': 24,
#                'NumberOfFeatures': 70,
#                'NumberOfInstances': 226,
#                'NumberOfInstancesWithMissingValues': 222,
#                'NumberOfMissingValues': 317,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 70}),
#              (8,
#               {'tid': 8,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 8,
#                'name': 'liver-disorders',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '8',
#                'target_feature': 'selector',
#                'NumberOfClasses': 0,
#                'NumberOfFeatures': 6,
#                'NumberOfInstances': 345,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 0}),
#              (9,
#               {'tid': 9,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 9,
#                'name': 'autos',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '9',
#                'target_feature': 'symboling',
#                'MajorityClassSize': 67,
#                'MaxNominalAttDistinctValues': 22,
#                'MinorityClassSize': 3,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 26,
#                'NumberOfInstances': 205,
#                'NumberOfInstancesWithMissingValues': 46,
#                'NumberOfMissingValues': 59,
#                'NumberOfNumericFeatures': 15,
#                'NumberOfSymbolicFeatures': 11}),
#              (10,
#               {'tid': 10,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 10,
#                'name': 'lymph',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '10',
#                'target_feature': 'class',
#                'MajorityClassSize': 81,
#                'MaxNominalAttDistinctValues': 8,
#                'MinorityClassSize': 2,
#                'NumberOfClasses': 4,
#                'NumberOfFeatures': 19,
#                'NumberOfInstances': 148,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 3,
#                'NumberOfSymbolicFeatures': 16}),
#              (11,
#               {'tid': 11,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 11,
#                'name': 'balance-scale',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '11',
#                'target_feature': 'class',
#                'MajorityClassSize': 288,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 49,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 5,
#                'NumberOfInstances': 625,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 4,
#                'NumberOfSymbolicFeatures': 1}),
#              (12,
#               {'tid': 12,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 12,
#                'name': 'mfeat-factors',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '12',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 217,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 216,
#                'NumberOfSymbolicFeatures': 1}),
#              (13,
#               {'tid': 13,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 13,
#                'name': 'breast-cancer',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '13',
#                'target_feature': 'Class',
#                'MajorityClassSize': 201,
#                'MaxNominalAttDistinctValues': 11,
#                'MinorityClassSize': 85,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 286,
#                'NumberOfInstancesWithMissingValues': 9,
#                'NumberOfMissingValues': 9,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 10}),
#              (14,
#               {'tid': 14,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 14,
#                'name': 'mfeat-fourier',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '14',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 77,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 76,
#                'NumberOfSymbolicFeatures': 1}),
#              (15,
#               {'tid': 15,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 15,
#                'name': 'breast-w',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '15',
#                'target_feature': 'Class',
#                'MajorityClassSize': 458,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 241,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 699,
#                'NumberOfInstancesWithMissingValues': 16,
#                'NumberOfMissingValues': 16,
#                'NumberOfNumericFeatures': 9,
#                'NumberOfSymbolicFeatures': 1}),
#              (16,
#               {'tid': 16,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 16,
#                'name': 'mfeat-karhunen',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '16',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 65,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 64,
#                'NumberOfSymbolicFeatures': 1}),
#              (18,
#               {'tid': 18,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 18,
#                'name': 'mfeat-morphological',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '18',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 7,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 1}),
#              (20,
#               {'tid': 20,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 20,
#                'name': 'mfeat-pixel',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '20',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 241,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 241}),
#              (22,
#               {'tid': 22,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 22,
#                'name': 'mfeat-zernike',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '22',
#                'target_feature': 'class',
#                'MajorityClassSize': 200,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 200,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 48,
#                'NumberOfInstances': 2000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 47,
#                'NumberOfSymbolicFeatures': 1}),
#              (23,
#               {'tid': 23,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 23,
#                'name': 'cmc',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '23',
#                'target_feature': 'Contraceptive_method_used',
#                'MajorityClassSize': 629,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 333,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 1473,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 2,
#                'NumberOfSymbolicFeatures': 8}),
#              (24,
#               {'tid': 24,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 24,
#                'name': 'mushroom',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '24',
#                'target_feature': 'class',
#                'MajorityClassSize': 4208,
#                'MaxNominalAttDistinctValues': 12,
#                'MinorityClassSize': 3916,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 23,
#                'NumberOfInstances': 8124,
#                'NumberOfInstancesWithMissingValues': 2480,
#                'NumberOfMissingValues': 2480,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 23}),
#              (25,
#               {'tid': 25,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 25,
#                'name': 'colic',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '25',
#                'target_feature': 'pathology_cp_data',
#                'MajorityClassSize': 232,
#                'MaxNominalAttDistinctValues': 63,
#                'MinorityClassSize': 136,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 27,
#                'NumberOfInstances': 368,
#                'NumberOfInstancesWithMissingValues': 361,
#                'NumberOfMissingValues': 1927,
#                'NumberOfNumericFeatures': 7,
#                'NumberOfSymbolicFeatures': 20}),
#              (26,
#               {'tid': 26,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 26,
#                'name': 'nursery',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '26',
#                'target_feature': 'class',
#                'MajorityClassSize': 4320,
#                'MaxNominalAttDistinctValues': 5,
#                'MinorityClassSize': 2,
#                'NumberOfClasses': 5,
#                'NumberOfFeatures': 9,
#                'NumberOfInstances': 12960,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 9}),
#              (27,
#               {'tid': 27,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 27,
#                'name': 'colic',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '27',
#                'target_feature': 'surgical_lesion',
#                'MajorityClassSize': 232,
#                'MaxNominalAttDistinctValues': 6,
#                'MinorityClassSize': 136,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 23,
#                'NumberOfInstances': 368,
#                'NumberOfInstancesWithMissingValues': 361,
#                'NumberOfMissingValues': 1927,
#                'NumberOfNumericFeatures': 7,
#                'NumberOfSymbolicFeatures': 16}),
#              (28,
#               {'tid': 28,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 28,
#                'name': 'optdigits',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '28',
#                'target_feature': 'class',
#                'MajorityClassSize': 572,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 554,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 65,
#                'NumberOfInstances': 5620,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 64,
#                'NumberOfSymbolicFeatures': 1}),
#              (29,
#               {'tid': 29,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 29,
#                'name': 'credit-approval',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '29',
#                'target_feature': 'class',
#                'MajorityClassSize': 383,
#                'MaxNominalAttDistinctValues': 14,
#                'MinorityClassSize': 307,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 16,
#                'NumberOfInstances': 690,
#                'NumberOfInstancesWithMissingValues': 37,
#                'NumberOfMissingValues': 67,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 10}),
#              (30,
#               {'tid': 30,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 30,
#                'name': 'page-blocks',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '30',
#                'target_feature': 'class',
#                'MajorityClassSize': 4913,
#                'MaxNominalAttDistinctValues': 5,
#                'MinorityClassSize': 28,
#                'NumberOfClasses': 5,
#                'NumberOfFeatures': 11,
#                'NumberOfInstances': 5473,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 10,
#                'NumberOfSymbolicFeatures': 1}),
#              (31,
#               {'tid': 31,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 31,
#                'name': 'credit-g',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '31',
#                'target_feature': 'class',
#                'MajorityClassSize': 700,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 300,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 21,
#                'NumberOfInstances': 1000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 7,
#                'NumberOfSymbolicFeatures': 14}),
#              (32,
#               {'tid': 32,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 32,
#                'name': 'pendigits',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '32',
#                'target_feature': 'class',
#                'MajorityClassSize': 1144,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 1055,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 10992,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 16,
#                'NumberOfSymbolicFeatures': 1}),
#              (34,
#               {'tid': 34,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 34,
#                'name': 'postoperative-patient-data',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '34',
#                'target_feature': 'decision',
#                'MajorityClassSize': 64,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 2,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 9,
#                'NumberOfInstances': 90,
#                'NumberOfInstancesWithMissingValues': 3,
#                'NumberOfMissingValues': 3,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 9}),
#              (35,
#               {'tid': 35,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 35,
#                'name': 'dermatology',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '35',
#                'target_feature': 'class',
#                'MajorityClassSize': 112,
#                'MaxNominalAttDistinctValues': 6,
#                'MinorityClassSize': 20,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 35,
#                'NumberOfInstances': 366,
#                'NumberOfInstancesWithMissingValues': 8,
#                'NumberOfMissingValues': 8,
#                'NumberOfNumericFeatures': 1,
#                'NumberOfSymbolicFeatures': 34}),
#              (36,
#               {'tid': 36,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 36,
#                'name': 'segment',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '36',
#                'target_feature': 'class',
#                'MajorityClassSize': 330,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 330,
#                'NumberOfClasses': 7,
#                'NumberOfFeatures': 20,
#                'NumberOfInstances': 2310,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 19,
#                'NumberOfSymbolicFeatures': 1}),
#              (37,
#               {'tid': 37,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 37,
#                'name': 'diabetes',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '37',
#                'target_feature': 'class',
#                'MajorityClassSize': 500,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 268,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 9,
#                'NumberOfInstances': 768,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 8,
#                'NumberOfSymbolicFeatures': 1}),
#              (38,
#               {'tid': 38,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 39,
#                'name': 'ecoli',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '39',
#                'target_feature': 'class',
#                'MajorityClassSize': 143,
#                'MaxNominalAttDistinctValues': 8,
#                'MinorityClassSize': 2,
#                'NumberOfClasses': 8,
#                'NumberOfFeatures': 8,
#                'NumberOfInstances': 336,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 7,
#                'NumberOfSymbolicFeatures': 1}),
#              (39,
#               {'tid': 39,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 40,
#                'name': 'sonar',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '40',
#                'target_feature': 'Class',
#                'MajorityClassSize': 111,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 97,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 61,
#                'NumberOfInstances': 208,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 60,
#                'NumberOfSymbolicFeatures': 1}),
#              (40,
#               {'tid': 40,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 41,
#                'name': 'glass',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '41',
#                'target_feature': 'Type',
#                'MajorityClassSize': 76,
#                'MaxNominalAttDistinctValues': 6,
#                'MinorityClassSize': 9,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 214,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 9,
#                'NumberOfSymbolicFeatures': 1}),
#              (41,
#               {'tid': 41,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 42,
#                'name': 'soybean',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '42',
#                'target_feature': 'class',
#                'MajorityClassSize': 92,
#                'MaxNominalAttDistinctValues': 19,
#                'MinorityClassSize': 8,
#                'NumberOfClasses': 19,
#                'NumberOfFeatures': 36,
#                'NumberOfInstances': 683,
#                'NumberOfInstancesWithMissingValues': 121,
#                'NumberOfMissingValues': 2337,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 36}),
#              (42,
#               {'tid': 42,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 43,
#                'name': 'haberman',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '43',
#                'target_feature': 'Survival_status',
#                'MajorityClassSize': 225,
#                'MaxNominalAttDistinctValues': 12,
#                'MinorityClassSize': 81,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 4,
#                'NumberOfInstances': 306,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 2,
#                'NumberOfSymbolicFeatures': 2}),
#              (43,
#               {'tid': 43,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 44,
#                'name': 'spambase',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '44',
#                'target_feature': 'class',
#                'MajorityClassSize': 2788,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 1813,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 58,
#                'NumberOfInstances': 4601,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 57,
#                'NumberOfSymbolicFeatures': 1}),
#              (45,
#               {'tid': 45,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 46,
#                'name': 'splice',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '46',
#                'target_feature': 'Class',
#                'MajorityClassSize': 1655,
#                'MaxNominalAttDistinctValues': 6,
#                'MinorityClassSize': 767,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 61,
#                'NumberOfInstances': 3190,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 61}),
#              (47,
#               {'tid': 47,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 48,
#                'name': 'tae',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '48',
#                'target_feature': 'Class_attribute',
#                'MajorityClassSize': 52,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 49,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 6,
#                'NumberOfInstances': 151,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 3,
#                'NumberOfSymbolicFeatures': 3}),
#              (48,
#               {'tid': 48,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 49,
#                'name': 'heart-c',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '49',
#                'target_feature': 'num',
#                'MajorityClassSize': 165,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 138,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 14,
#                'NumberOfInstances': 303,
#                'NumberOfInstancesWithMissingValues': 7,
#                'NumberOfMissingValues': 7,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 8}),
#              (49,
#               {'tid': 49,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 50,
#                'name': 'tic-tac-toe',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '50',
#                'target_feature': 'Class',
#                'MajorityClassSize': 626,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 332,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 958,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 10}),
#              (50,
#               {'tid': 50,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 51,
#                'name': 'heart-h',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '51',
#                'target_feature': 'num',
#                'MajorityClassSize': 188,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 106,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 14,
#                'NumberOfInstances': 294,
#                'NumberOfInstancesWithMissingValues': 293,
#                'NumberOfMissingValues': 782,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 8}),
#              (51,
#               {'tid': 51,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 52,
#                'name': 'trains',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '52',
#                'target_feature': 'class',
#                'MajorityClassSize': 5,
#                'MaxNominalAttDistinctValues': 8,
#                'MinorityClassSize': 5,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 33,
#                'NumberOfInstances': 10,
#                'NumberOfInstancesWithMissingValues': 7,
#                'NumberOfMissingValues': 51,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 33}),
#              (52,
#               {'tid': 52,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 53,
#                'name': 'heart-statlog',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '53',
#                'target_feature': 'class',
#                'MajorityClassSize': 150,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 120,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 14,
#                'NumberOfInstances': 270,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 13,
#                'NumberOfSymbolicFeatures': 1}),
#              (53,
#               {'tid': 53,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 54,
#                'name': 'vehicle',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '54',
#                'target_feature': 'Class',
#                'MajorityClassSize': 218,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 199,
#                'NumberOfClasses': 4,
#                'NumberOfFeatures': 19,
#                'NumberOfInstances': 846,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 18,
#                'NumberOfSymbolicFeatures': 1}),
#              (54,
#               {'tid': 54,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 55,
#                'name': 'hepatitis',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '55',
#                'target_feature': 'Class',
#                'MajorityClassSize': 123,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 32,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 20,
#                'NumberOfInstances': 155,
#                'NumberOfInstancesWithMissingValues': 75,
#                'NumberOfMissingValues': 167,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 14}),
#              (55,
#               {'tid': 55,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 56,
#                'name': 'vote',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '56',
#                'target_feature': 'Class',
#                'MajorityClassSize': 267,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 168,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 435,
#                'NumberOfInstancesWithMissingValues': 203,
#                'NumberOfMissingValues': 392,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 17}),
#              (57,
#               {'tid': 57,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 59,
#                'name': 'ionosphere',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '59',
#                'target_feature': 'class',
#                'MajorityClassSize': 225,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 126,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 35,
#                'NumberOfInstances': 351,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 34,
#                'NumberOfSymbolicFeatures': 1}),
#              (58,
#               {'tid': 58,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 60,
#                'name': 'waveform-5000',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'source_data': '60',
#                'target_feature': 'class',
#                'MajorityClassSize': 1692,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 1653,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 41,
#                'NumberOfInstances': 5000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 40,
#                'NumberOfSymbolicFeatures': 1}),
#              (59,
#               {'tid': 59,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 61,
#                'name': 'iris',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '61',
#                'target_feature': 'class',
#                'MajorityClassSize': 50,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 50,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 5,
#                'NumberOfInstances': 150,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 4,
#                'NumberOfSymbolicFeatures': 1}),
#              (60,
#               {'tid': 60,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 62,
#                'name': 'zoo',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '62',
#                'target_feature': 'type',
#                'MajorityClassSize': 41,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 4,
#                'NumberOfClasses': 7,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 101,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 1,
#                'NumberOfSymbolicFeatures': 16}),
#              (62,
#               {'tid': 62,
#                'ttid': <TaskType.LEARNING_CURVE: 3>,
#                'did': 2,
#                'name': 'anneal',
#                'task_type': 'Learning Curve',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Learning Curve',
#                'evaluation_measures': 'predictive_accuracy',
#                'number_samples': '9',
#                'source_data': '2',
#                'target_feature': 'class',
#                'MajorityClassSize': 684,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 8,
#                'NumberOfClasses': 5,
#                'NumberOfFeatures': 39,
#                'NumberOfInstances': 898,
#                'NumberOfInstancesWithMissingValues': 898,
#                'NumberOfMissingValues': 22175,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 33}),
#              (63,
#               {'tid': 63,
#                'ttid': <TaskType.LEARNING_CURVE: 3>,
#                'did': 3,
#                'name': 'kr-vs-kp',
#                'task_type': 'Learning Curve',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Learning Curve',
#                'evaluation_measures': 'predictive_accuracy',
#                'number_samples': '12',
#                'source_data': '3',
#                'target_feature': 'class',
#                'MajorityClassSize': 1669,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 1527,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 37,
#                'NumberOfInstances': 3196,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 37}),
#              (64,
#               {'tid': 64,
#                'ttid': <TaskType.LEARNING_CURVE: 3>,
#                'did': 4,
#                'name': 'labor',
#                'task_type': 'Learning Curve',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Learning Curve',
#                'evaluation_measures': 'predictive_accuracy',
#                'number_samples': '1',
# ...
#                'NumberOfSymbolicFeatures': 2}),
#              (2941,
#               {'tid': 2941,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 184,
#                'name': 'kropt',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '184',
#                'target_feature': 'game',
#                'MajorityClassSize': 4553,
#                'MaxNominalAttDistinctValues': 18,
#                'MinorityClassSize': 27,
#                'NumberOfClasses': 18,
#                'NumberOfFeatures': 7,
#                'NumberOfInstances': 28056,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 0,
#                'NumberOfSymbolicFeatures': 7}),
#              (2942,
#               {'tid': 2942,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 185,
#                'name': 'baseball',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '185',
#                'target_feature': 'Hall_of_Fame',
#                'MajorityClassSize': 1215,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 57,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 1340,
#                'NumberOfInstancesWithMissingValues': 20,
#                'NumberOfMissingValues': 20,
#                'NumberOfNumericFeatures': 15,
#                'NumberOfSymbolicFeatures': 2}),
#              (2943,
#               {'tid': 2943,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 186,
#                'name': 'braziltourism',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '186',
#                'target_feature': 'Trips',
#                'MajorityClassSize': 318,
#                'MaxNominalAttDistinctValues': 7,
#                'MinorityClassSize': 1,
#                'NumberOfClasses': 7,
#                'NumberOfFeatures': 9,
#                'NumberOfInstances': 412,
#                'NumberOfInstancesWithMissingValues': 49,
#                'NumberOfMissingValues': 96,
#                'NumberOfNumericFeatures': 4,
#                'NumberOfSymbolicFeatures': 5}),
#              (2944,
#               {'tid': 2944,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 188,
#                'name': 'eucalyptus',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '188',
#                'target_feature': 'Utility',
#                'MajorityClassSize': 214,
#                'MaxNominalAttDistinctValues': 27,
#                'MinorityClassSize': 105,
#                'NumberOfClasses': 5,
#                'NumberOfFeatures': 20,
#                'NumberOfInstances': 736,
#                'NumberOfInstancesWithMissingValues': 95,
#                'NumberOfMissingValues': 448,
#                'NumberOfNumericFeatures': 14,
#                'NumberOfSymbolicFeatures': 6}),
#              (2945,
#               {'tid': 2945,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 244,
#                'name': 'BNG(anneal)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '244',
#                'target_feature': 'class',
#                'MajorityClassSize': 759652,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 555,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 39,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 33}),
#              (2946,
#               {'tid': 2946,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 245,
#                'name': 'BNG(anneal.ORIG)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '245',
#                'target_feature': 'class',
#                'MajorityClassSize': 759652,
#                'MaxNominalAttDistinctValues': 9,
#                'MinorityClassSize': 555,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 39,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 6,
#                'NumberOfSymbolicFeatures': 33}),
#              (2947,
#               {'tid': 2947,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 246,
#                'name': 'BNG(labor)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '246',
#                'target_feature': 'class',
#                'MajorityClassSize': 647000,
#                'MaxNominalAttDistinctValues': 3,
#                'MinorityClassSize': 353000,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 8,
#                'NumberOfSymbolicFeatures': 9}),
#              (2948,
#               {'tid': 2948,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 247,
#                'name': 'BNG(letter)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '247',
#                'target_feature': 'class',
#                'MajorityClassSize': 40765,
#                'MaxNominalAttDistinctValues': 26,
#                'MinorityClassSize': 36811,
#                'NumberOfClasses': 26,
#                'NumberOfFeatures': 17,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 16,
#                'NumberOfSymbolicFeatures': 1}),
#              (2949,
#               {'tid': 2949,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 248,
#                'name': 'BNG(autos)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '248',
#                'target_feature': 'symboling',
#                'MajorityClassSize': 323554,
#                'MaxNominalAttDistinctValues': 22,
#                'MinorityClassSize': 2441,
#                'NumberOfClasses': 7,
#                'NumberOfFeatures': 26,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 15,
#                'NumberOfSymbolicFeatures': 11}),
#              (2950,
#               {'tid': 2950,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 249,
#                'name': 'BNG(lymph)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '249',
#                'target_feature': 'class',
#                'MajorityClassSize': 543495,
#                'MaxNominalAttDistinctValues': 8,
#                'MinorityClassSize': 16508,
#                'NumberOfClasses': 4,
#                'NumberOfFeatures': 19,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 3,
#                'NumberOfSymbolicFeatures': 16}),
#              (2951,
#               {'tid': 2951,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 250,
#                'name': 'BNG(mfeat-fourier)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '250',
#                'target_feature': 'class',
#                'MajorityClassSize': 100515,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 99530,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 77,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 76,
#                'NumberOfSymbolicFeatures': 1}),
#              (2952,
#               {'tid': 2952,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 251,
#                'name': 'BNG(breast-w)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '251',
#                'target_feature': 'Class',
#                'MajorityClassSize': 25820,
#                'MaxNominalAttDistinctValues': 2,
#                'MinorityClassSize': 13546,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 39366,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 9,
#                'NumberOfSymbolicFeatures': 1}),
#              (2953,
#               {'tid': 2953,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 252,
#                'name': 'BNG(mfeat-karhunen)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '252',
#                'target_feature': 'class',
#                'MajorityClassSize': 100410,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 99545,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 65,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 64,
#                'NumberOfSymbolicFeatures': 1}),
#              (2954,
#               {'tid': 2954,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 253,
#                'name': 'BNG(bridges_version1)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '253',
#                'target_feature': 'TYPE',
#                'MajorityClassSize': 423139,
#                'MaxNominalAttDistinctValues': 108,
#                'MinorityClassSize': 95207,
#                'NumberOfClasses': 6,
#                'NumberOfFeatures': 13,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 3,
#                'NumberOfSymbolicFeatures': 10}),
#              (2955,
#               {'tid': 2955,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 254,
#                'name': 'BNG(mfeat-zernike)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '254',
#                'target_feature': 'class',
#                'MajorityClassSize': 100289,
#                'MaxNominalAttDistinctValues': 10,
#                'MinorityClassSize': 99797,
#                'NumberOfClasses': 10,
#                'NumberOfFeatures': 48,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 47,
#                'NumberOfSymbolicFeatures': 1}),
#              (2956,
#               {'tid': 2956,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 255,
#                'name': 'BNG(cmc)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '255',
#                'target_feature': 'Contraceptive_method_used',
#                'MajorityClassSize': 23567,
#                'MaxNominalAttDistinctValues': 4,
#                'MinorityClassSize': 12447,
#                'NumberOfClasses': 3,
#                'NumberOfFeatures': 10,
#                'NumberOfInstances': 55296,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 2,
#                'NumberOfSymbolicFeatures': 8}),
#              (2957,
#               {'tid': 2957,
#                'ttid': <TaskType.SUPERVISED_CLASSIFICATION: 1>,
#                'did': 256,
#                'name': 'BNG(colic.ORIG)',
#                'task_type': 'Supervised Classification',
#                'status': 'active',
#                'estimation_procedure': '10 times 10-fold Crossvalidation',
#                'evaluation_measures': 'predictive_accuracy',
#                'source_data': '256',
#                'target_feature': 'pathology_cp_data',
#                'MajorityClassSize': 637594,
#                'MaxNominalAttDistinctValues': 338,
#                'MinorityClassSize': 362406,
#                'NumberOfClasses': 2,
#                'NumberOfFeatures': 28,
#                'NumberOfInstances': 1000000,
#                'NumberOfInstancesWithMissingValues': 0,
#                'NumberOfMissingValues': 0,
#                'NumberOfNumericFeatures': 7,
#                'NumberOfSymbolicFeatures': 21}),
#              ...])
